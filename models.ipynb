# %%
# Install required packages.
import os
import torch
from torchmetrics import AUROC
os.environ['TORCH'] = torch.__version__
print(torch.__version__)
# Out:
# 2.2.1

# %%
from torch_geometric.datasets import TUDataset
train_dataset = TUDataset(root='data/TUDataset', name='Tox21_AhR_training')
test_dataset = TUDataset(root='data/TUDataset', name='Tox21_AhR_testing')

# %%
import torch
from torch_geometric.datasets import TUDataset

print()
print(f'Dataset: {train_dataset}:')
print('====================')
print(f'Number of graphs: {len(train_dataset)}')
print(f'Number of features: {train_dataset.num_features}')
print(f'Number of classes: {train_dataset.num_classes}')

data = train_dataset[0]  # Get the first graph object.

print()
print(data)
print('=============================================================')

# Gather some statistics about the first graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')

print()
print(f'Dataset: {test_dataset}:')
print('====================')
print(f'Number of graphs: {len(test_dataset)}')
print(f'Number of features: {test_dataset.num_features}')
print(f'Number of classes: {test_dataset.num_classes}')

data = test_dataset[0]  # Get the first graph object.

print()
print(data)
print('=============================================================')

# Gather some statistics about the first graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
# Out:
# Dataset: Tox21_AhR_training(8169):
# ====================
# Number of graphs: 8169
# Number of features: 50
# Number of classes: 2
#
# Data(edge_index=[2, 52], x=[25, 50], edge_attr=[52, 4], y=[1])
# =============================================================
# Number of nodes: 25
# Number of edges: 52
# Average node degree: 2.08
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: True
#
# Dataset: Tox21_AhR_testing(272):
# ====================
# Number of graphs: 272
# Number of features: 51
# Number of classes: 2
#
# Data(edge_index=[2, 44], x=[20, 51], edge_attr=[44, 4], y=[1])
# =============================================================
# Number of nodes: 20
# Number of edges: 44
# Average node degree: 2.20
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: True

# %%
dataset = train_dataset.shuffle()
# test_dataset = test_dataset.shuffle()

split = int(len(dataset) * 0.80)
train_dataset = dataset[:split]
test_dataset = dataset[split:]

print(f'Number of training graphs: {len(train_dataset)}')
print(f'Number of test graphs: {len(test_dataset)}')
# Out:
# Number of training graphs: 6535
# Number of test graphs: 1634

# %%
from torch_geometric.loader import DataLoader

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

for step, data in enumerate(train_loader):
    print(f'Step {step + 1}:')
    print('=======')
    print(f'Number of graphs in the current batch: {data.num_graphs}')
    print(data)
    print()
# Out:
# Step 1:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2342], x=[1157, 50], edge_attr=[2342, 4], y=[64], batch=[1157], ptr=[65])
#
# Step 2:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2146], x=[1067, 50], edge_attr=[2146, 4], y=[64], batch=[1067], ptr=[65])
#
# Step 3:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2274], x=[1115, 50], edge_attr=[2274, 4], y=[64], batch=[1115], ptr=[65])
#
# Step 4:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2172], x=[1074, 50], edge_attr=[2172, 4], y=[64], batch=[1074], ptr=[65])
#
# Step 5:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2510], x=[1219, 50], edge_attr=[2510, 4], y=[64], batch=[1219], ptr=[65])
#
# Step 6:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2058], x=[1003, 50], edge_attr=[2058, 4], y=[64], batch=[1003], ptr=[65])
#
# Step 7:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2366], x=[1168, 50], edge_attr=[2366, 4], y=[64], batch=[1168], ptr=[65])
#
# Step 8:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2668], x=[1313, 50], edge_attr=[2668, 4], y=[64], batch=[1313], ptr=[65])
#
# Step 9:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2096], x=[1028, 50], edge_attr=[2096, 4], y=[64], batch=[1028], ptr=[65])
#
# Step 10:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2412], x=[1161, 50], edge_attr=[2412, 4], y=[64], batch=[1161], ptr=[65])
#
# Step 11:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2460], x=[1205, 50], edge_attr=[2460, 4], y=[64], batch=[1205], ptr=[65])
#
# Step 12:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2160], x=[1049, 50], edge_attr=[2160, 4], y=[64], batch=[1049], ptr=[65])
#
# Step 13:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 1968], x=[965, 50], edge_attr=[1968, 4], y=[64], batch=[965], ptr=[65])
#
# Step 14:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2546], x=[1251, 50], edge_attr=[2546, 4], y=[64], batch=[1251], ptr=[65])
#
# Step 15:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2296], x=[1120, 50], edge_attr=[2296, 4], y=[64], batch=[1120], ptr=[65])
#
# Step 16:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2728], x=[1317, 50], edge_attr=[2728, 4], y=[64], batch=[1317], ptr=[65])
#
# Step 17:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2860], x=[1378, 50], edge_attr=[2860, 4], y=[64], batch=[1378], ptr=[65])
#
# Step 18:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2818], x=[1350, 50], edge_attr=[2818, 4], y=[64], batch=[1350], ptr=[65])
#
# Step 19:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2178], x=[1075, 50], edge_attr=[2178, 4], y=[64], batch=[1075], ptr=[65])
#
# Step 20:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2318], x=[1136, 50], edge_attr=[2318, 4], y=[64], batch=[1136], ptr=[65])
#
# Step 21:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2260], x=[1113, 50], edge_attr=[2260, 4], y=[64], batch=[1113], ptr=[65])
#
# Step 22:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2356], x=[1164, 50], edge_attr=[2356, 4], y=[64], batch=[1164], ptr=[65])
#
# Step 23:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2102], x=[1031, 50], edge_attr=[2102, 4], y=[64], batch=[1031], ptr=[65])
#
# Step 24:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2456], x=[1180, 50], edge_attr=[2456, 4], y=[64], batch=[1180], ptr=[65])
#
# Step 25:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2190], x=[1090, 50], edge_attr=[2190, 4], y=[64], batch=[1090], ptr=[65])
#
# Step 26:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2640], x=[1282, 50], edge_attr=[2640, 4], y=[64], batch=[1282], ptr=[65])
#
# Step 27:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2292], x=[1132, 50], edge_attr=[2292, 4], y=[64], batch=[1132], ptr=[65])
#
# Step 28:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2174], x=[1060, 50], edge_attr=[2174, 4], y=[64], batch=[1060], ptr=[65])
#
# Step 29:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2382], x=[1177, 50], edge_attr=[2382, 4], y=[64], batch=[1177], ptr=[65])
#
# Step 30:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2584], x=[1261, 50], edge_attr=[2584, 4], y=[64], batch=[1261], ptr=[65])
#
# Step 31:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2350], x=[1159, 50], edge_attr=[2350, 4], y=[64], batch=[1159], ptr=[65])
#
# Step 32:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2762], x=[1353, 50], edge_attr=[2762, 4], y=[64], batch=[1353], ptr=[65])
#
# Step 33:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2522], x=[1235, 50], edge_attr=[2522, 4], y=[64], batch=[1235], ptr=[65])
#
# Step 34:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2664], x=[1292, 50], edge_attr=[2664, 4], y=[64], batch=[1292], ptr=[65])
#
# Step 35:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2302], x=[1121, 50], edge_attr=[2302, 4], y=[64], batch=[1121], ptr=[65])
#
# Step 36:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2446], x=[1197, 50], edge_attr=[2446, 4], y=[64], batch=[1197], ptr=[65])
#
# Step 37:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2014], x=[1013, 50], edge_attr=[2014, 4], y=[64], batch=[1013], ptr=[65])
#
# Step 38:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2138], x=[1044, 50], edge_attr=[2138, 4], y=[64], batch=[1044], ptr=[65])
#
# Step 39:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2284], x=[1108, 50], edge_attr=[2284, 4], y=[64], batch=[1108], ptr=[65])
#
# Step 40:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2578], x=[1245, 50], edge_attr=[2578, 4], y=[64], batch=[1245], ptr=[65])
#
# Step 41:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2466], x=[1194, 50], edge_attr=[2466, 4], y=[64], batch=[1194], ptr=[65])
#
# Step 42:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2378], x=[1149, 50], edge_attr=[2378, 4], y=[64], batch=[1149], ptr=[65])
#
# Step 43:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2632], x=[1276, 50], edge_attr=[2632, 4], y=[64], batch=[1276], ptr=[65])
#
# Step 44:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2124], x=[1056, 50], edge_attr=[2124, 4], y=[64], batch=[1056], ptr=[65])
#
# Step 45:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2252], x=[1116, 50], edge_attr=[2252, 4], y=[64], batch=[1116], ptr=[65])
#
# Step 46:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2174], x=[1061, 50], edge_attr=[2174, 4], y=[64], batch=[1061], ptr=[65])
#
# Step 47:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2028], x=[996, 50], edge_attr=[2028, 4], y=[64], batch=[996], ptr=[65])
#
# Step 48:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2528], x=[1224, 50], edge_attr=[2528, 4], y=[64], batch=[1224], ptr=[65])
#
# Step 49:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2660], x=[1279, 50], edge_attr=[2660, 4], y=[64], batch=[1279], ptr=[65])
#
# Step 50:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2226], x=[1095, 50], edge_attr=[2226, 4], y=[64], batch=[1095], ptr=[65])
#
# Step 51:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2598], x=[1261, 50], edge_attr=[2598, 4], y=[64], batch=[1261], ptr=[65])
#
# Step 52:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2284], x=[1120, 50], edge_attr=[2284, 4], y=[64], batch=[1120], ptr=[65])
#
# Step 53:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2584], x=[1254, 50], edge_attr=[2584, 4], y=[64], batch=[1254], ptr=[65])
#
# Step 54:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2204], x=[1080, 50], edge_attr=[2204, 4], y=[64], batch=[1080], ptr=[65])
#
# Step 55:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2990], x=[1434, 50], edge_attr=[2990, 4], y=[64], batch=[1434], ptr=[65])
#
# Step 56:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2362], x=[1162, 50], edge_attr=[2362, 4], y=[64], batch=[1162], ptr=[65])
#
# Step 57:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2478], x=[1199, 50], edge_attr=[2478, 4], y=[64], batch=[1199], ptr=[65])
#
# Step 58:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2478], x=[1220, 50], edge_attr=[2478, 4], y=[64], batch=[1220], ptr=[65])
#
# Step 59:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2010], x=[980, 50], edge_attr=[2010, 4], y=[64], batch=[980], ptr=[65])
#
# Step 60:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2434], x=[1195, 50], edge_attr=[2434, 4], y=[64], batch=[1195], ptr=[65])
#
# Step 61:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2344], x=[1160, 50], edge_attr=[2344, 4], y=[64], batch=[1160], ptr=[65])
#
# Step 62:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 1966], x=[980, 50], edge_attr=[1966, 4], y=[64], batch=[980], ptr=[65])
#
# Step 63:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2462], x=[1185, 50], edge_attr=[2462, 4], y=[64], batch=[1185], ptr=[65])
#
# Step 64:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2382], x=[1174, 50], edge_attr=[2382, 4], y=[64], batch=[1174], ptr=[65])
#
# Step 65:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2676], x=[1302, 50], edge_attr=[2676, 4], y=[64], batch=[1302], ptr=[65])
#
# Step 66:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2386], x=[1165, 50], edge_attr=[2386, 4], y=[64], batch=[1165], ptr=[65])
#
# Step 67:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2332], x=[1133, 50], edge_attr=[2332, 4], y=[64], batch=[1133], ptr=[65])
#
# Step 68:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2342], x=[1148, 50], edge_attr=[2342, 4], y=[64], batch=[1148], ptr=[65])
#
# Step 69:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2456], x=[1201, 50], edge_attr=[2456, 4], y=[64], batch=[1201], ptr=[65])
#
# Step 70:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2472], x=[1198, 50], edge_attr=[2472, 4], y=[64], batch=[1198], ptr=[65])
#
# Step 71:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2434], x=[1183, 50], edge_attr=[2434, 4], y=[64], batch=[1183], ptr=[65])
#
# Step 72:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2226], x=[1100, 50], edge_attr=[2226, 4], y=[64], batch=[1100], ptr=[65])
#
# Step 73:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2470], x=[1198, 50], edge_attr=[2470, 4], y=[64], batch=[1198], ptr=[65])
#
# Step 74:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2796], x=[1358, 50], edge_attr=[2796, 4], y=[64], batch=[1358], ptr=[65])
#
# Step 75:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2384], x=[1167, 50], edge_attr=[2384, 4], y=[64], batch=[1167], ptr=[65])
#
# Step 76:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2144], x=[1063, 50], edge_attr=[2144, 4], y=[64], batch=[1063], ptr=[65])
#
# Step 77:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2628], x=[1278, 50], edge_attr=[2628, 4], y=[64], batch=[1278], ptr=[65])
#
# Step 78:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2448], x=[1199, 50], edge_attr=[2448, 4], y=[64], batch=[1199], ptr=[65])
#
# Step 79:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2386], x=[1173, 50], edge_attr=[2386, 4], y=[64], batch=[1173], ptr=[65])
#
# Step 80:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2228], x=[1100, 50], edge_attr=[2228, 4], y=[64], batch=[1100], ptr=[65])
#
# Step 81:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2354], x=[1154, 50], edge_attr=[2354, 4], y=[64], batch=[1154], ptr=[65])
#
# Step 82:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2372], x=[1159, 50], edge_attr=[2372, 4], y=[64], batch=[1159], ptr=[65])
#
# Step 83:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2444], x=[1197, 50], edge_attr=[2444, 4], y=[64], batch=[1197], ptr=[65])
#
# Step 84:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2270], x=[1102, 50], edge_attr=[2270, 4], y=[64], batch=[1102], ptr=[65])
#
# Step 85:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2624], x=[1266, 50], edge_attr=[2624, 4], y=[64], batch=[1266], ptr=[65])
#
# Step 86:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2258], x=[1101, 50], edge_attr=[2258, 4], y=[64], batch=[1101], ptr=[65])
#
# Step 87:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2454], x=[1205, 50], edge_attr=[2454, 4], y=[64], batch=[1205], ptr=[65])
#
# Step 88:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2336], x=[1153, 50], edge_attr=[2336, 4], y=[64], batch=[1153], ptr=[65])
#
# Step 89:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2582], x=[1247, 50], edge_attr=[2582, 4], y=[64], batch=[1247], ptr=[65])
#
# Step 90:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2078], x=[1015, 50], edge_attr=[2078, 4], y=[64], batch=[1015], ptr=[65])
#
# Step 91:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2228], x=[1095, 50], edge_attr=[2228, 4], y=[64], batch=[1095], ptr=[65])
#
# Step 92:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2584], x=[1257, 50], edge_attr=[2584, 4], y=[64], batch=[1257], ptr=[65])
#
# Step 93:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2300], x=[1132, 50], edge_attr=[2300, 4], y=[64], batch=[1132], ptr=[65])
#
# Step 94:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2154], x=[1063, 50], edge_attr=[2154, 4], y=[64], batch=[1063], ptr=[65])
#
# Step 95:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2386], x=[1170, 50], edge_attr=[2386, 4], y=[64], batch=[1170], ptr=[65])
#
# Step 96:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2680], x=[1295, 50], edge_attr=[2680, 4], y=[64], batch=[1295], ptr=[65])
#
# Step 97:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2432], x=[1212, 50], edge_attr=[2432, 4], y=[64], batch=[1212], ptr=[65])
#
# Step 98:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2126], x=[1036, 50], edge_attr=[2126, 4], y=[64], batch=[1036], ptr=[65])
#
# Step 99:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2396], x=[1167, 50], edge_attr=[2396, 4], y=[64], batch=[1167], ptr=[65])
#
# Step 100:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2440], x=[1188, 50], edge_attr=[2440, 4], y=[64], batch=[1188], ptr=[65])
#
# Step 101:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2284], x=[1118, 50], edge_attr=[2284, 4], y=[64], batch=[1118], ptr=[65])
#
# Step 102:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2236], x=[1087, 50], edge_attr=[2236, 4], y=[64], batch=[1087], ptr=[65])
#
# Step 103:
# =======
# Number of graphs in the current batch: 7
# DataBatch(edge_index=[2, 448], x=[214, 50], edge_attr=[448, 4], y=[7], batch=[214], ptr=[8])

# %%
for step, data in enumerate(test_loader):
    print(f'Step {step + 1}:')
    print('=======')
    print(f'Number of graphs in the current batch: {data.num_graphs}')
    print(data)
    print()
# Out:
# Step 1:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 1972], x=[971, 50], edge_attr=[1972, 4], y=[64], batch=[971], ptr=[65])
#
# Step 2:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2452], x=[1206, 50], edge_attr=[2452, 4], y=[64], batch=[1206], ptr=[65])
#
# Step 3:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2300], x=[1120, 50], edge_attr=[2300, 4], y=[64], batch=[1120], ptr=[65])
#
# Step 4:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2390], x=[1168, 50], edge_attr=[2390, 4], y=[64], batch=[1168], ptr=[65])
#
# Step 5:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2134], x=[1052, 50], edge_attr=[2134, 4], y=[64], batch=[1052], ptr=[65])
#
# Step 6:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2254], x=[1092, 50], edge_attr=[2254, 4], y=[64], batch=[1092], ptr=[65])
#
# Step 7:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2062], x=[1021, 50], edge_attr=[2062, 4], y=[64], batch=[1021], ptr=[65])
#
# Step 8:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2698], x=[1323, 50], edge_attr=[2698, 4], y=[64], batch=[1323], ptr=[65])
#
# Step 9:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2498], x=[1241, 50], edge_attr=[2498, 4], y=[64], batch=[1241], ptr=[65])
#
# Step 10:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2322], x=[1135, 50], edge_attr=[2322, 4], y=[64], batch=[1135], ptr=[65])
#
# Step 11:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2214], x=[1074, 50], edge_attr=[2214, 4], y=[64], batch=[1074], ptr=[65])
#
# Step 12:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2512], x=[1225, 50], edge_attr=[2512, 4], y=[64], batch=[1225], ptr=[65])
#
# Step 13:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2040], x=[1017, 50], edge_attr=[2040, 4], y=[64], batch=[1017], ptr=[65])
#
# Step 14:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2348], x=[1149, 50], edge_attr=[2348, 4], y=[64], batch=[1149], ptr=[65])
#
# Step 15:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2300], x=[1127, 50], edge_attr=[2300, 4], y=[64], batch=[1127], ptr=[65])
#
# Step 16:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2164], x=[1064, 50], edge_attr=[2164, 4], y=[64], batch=[1064], ptr=[65])
#
# Step 17:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2148], x=[1059, 50], edge_attr=[2148, 4], y=[64], batch=[1059], ptr=[65])
#
# Step 18:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2694], x=[1307, 50], edge_attr=[2694, 4], y=[64], batch=[1307], ptr=[65])
#
# Step 19:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2110], x=[1046, 50], edge_attr=[2110, 4], y=[64], batch=[1046], ptr=[65])
#
# Step 20:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2662], x=[1291, 50], edge_attr=[2662, 4], y=[64], batch=[1291], ptr=[65])
#
# Step 21:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2058], x=[1011, 50], edge_attr=[2058, 4], y=[64], batch=[1011], ptr=[65])
#
# Step 22:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2288], x=[1126, 50], edge_attr=[2288, 4], y=[64], batch=[1126], ptr=[65])
#
# Step 23:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2394], x=[1174, 50], edge_attr=[2394, 4], y=[64], batch=[1174], ptr=[65])
#
# Step 24:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2276], x=[1110, 50], edge_attr=[2276, 4], y=[64], batch=[1110], ptr=[65])
#
# Step 25:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 2506], x=[1213, 50], edge_attr=[2506, 4], y=[64], batch=[1213], ptr=[65])
#
# Step 26:
# =======
# Number of graphs in the current batch: 34
# DataBatch(edge_index=[2, 1214], x=[600, 50], edge_attr=[1214, 4], y=[34], batch=[600], ptr=[35])

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_mean_pool, global_max_pool, global_add_pool


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(train_dataset.num_node_features, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, train_dataset.num_classes)

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)

        # 2. Readout layer
        x = global_add_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)

        return x

model = GCN(hidden_channels=64)
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(50, 64)
#   (conv2): GCNConv(64, 64)
#   (conv3): GCNConv(64, 64)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
model = GCN(hidden_channels=64)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()
auroc = AUROC(task="binary")

def train():
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
         out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
         loss = criterion(out, data.y)  # Compute the loss.
         loss.backward()  # Derive gradients.
         optimizer.step()  # Update parameters based on gradients.
         optimizer.zero_grad()  # Clear gradients.

def test(loader):
     model.eval()

     correct = 0
     for data in loader:  # Iterate in batches over the training/test dataset.
         out = model(data.x, data.edge_index, data.batch)
         pred = out.argmax(dim=1)  # Use the class with highest probability.
         correct += int((pred == data.y).sum())  # Check against ground-truth labels.
     return (correct / len(loader.dataset), auroc(out.softmax(dim=1)[:, 1], data.y))  # Derive ratio of correct predictions.


for epoch in range(1, 50):
    train()
    train_acc, train_auc = test(train_loader)
    test_acc, test_auc = test(test_loader)
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}, Test AUC: {test_auc:.4f}')
# Out:
# Epoch: 001, Train Acc: 0.8834, Test Acc: 0.8849, Test AUC: 0.7202
# /Users/mihirarya/Dev/bcil/gnn-drug-discovery/env/lib/python3.11/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Epoch: 002, Train Acc: 0.8834, Test Acc: 0.8849, Test AUC: 0.6964
# Epoch: 003, Train Acc: 0.8836, Test Acc: 0.8843, Test AUC: 0.7321
# Epoch: 004, Train Acc: 0.8837, Test Acc: 0.8849, Test AUC: 0.7024
# Epoch: 005, Train Acc: 0.8849, Test Acc: 0.8898, Test AUC: 0.7381
# Epoch: 006, Train Acc: 0.8851, Test Acc: 0.8874, Test AUC: 0.6667
# Epoch: 007, Train Acc: 0.8848, Test Acc: 0.8874, Test AUC: 0.7798
# Epoch: 008, Train Acc: 0.8852, Test Acc: 0.8868, Test AUC: 0.7500
# Epoch: 009, Train Acc: 0.8855, Test Acc: 0.8892, Test AUC: 0.8512
# Epoch: 010, Train Acc: 0.8842, Test Acc: 0.8874, Test AUC: 0.8036
# Epoch: 011, Train Acc: 0.8834, Test Acc: 0.8849, Test AUC: 0.8571
# Epoch: 012, Train Acc: 0.8836, Test Acc: 0.8856, Test AUC: 0.8393
# Epoch: 013, Train Acc: 0.8855, Test Acc: 0.8886, Test AUC: 0.8631
# Epoch: 014, Train Acc: 0.8860, Test Acc: 0.8911, Test AUC: 0.8988
# Epoch: 015, Train Acc: 0.8837, Test Acc: 0.8862, Test AUC: 0.8333
# Epoch: 016, Train Acc: 0.8857, Test Acc: 0.8911, Test AUC: 0.8929
# Epoch: 017, Train Acc: 0.8858, Test Acc: 0.8911, Test AUC: 0.8631
# Epoch: 018, Train Acc: 0.8860, Test Acc: 0.8892, Test AUC: 0.8631
# Epoch: 019, Train Acc: 0.8862, Test Acc: 0.8905, Test AUC: 0.8452
# Epoch: 020, Train Acc: 0.8834, Test Acc: 0.8849, Test AUC: 0.7976
# Epoch: 021, Train Acc: 0.8858, Test Acc: 0.8886, Test AUC: 0.8571
# Epoch: 022, Train Acc: 0.8874, Test Acc: 0.8892, Test AUC: 0.8274
# Epoch: 023, Train Acc: 0.8834, Test Acc: 0.8843, Test AUC: 0.8452
# Epoch: 024, Train Acc: 0.8860, Test Acc: 0.8886, Test AUC: 0.8810
# Epoch: 025, Train Acc: 0.8843, Test Acc: 0.8849, Test AUC: 0.8214
# Epoch: 026, Train Acc: 0.8848, Test Acc: 0.8874, Test AUC: 0.8155
# Epoch: 027, Train Acc: 0.8842, Test Acc: 0.8849, Test AUC: 0.7976
# Epoch: 028, Train Acc: 0.8868, Test Acc: 0.8892, Test AUC: 0.8333
# Epoch: 029, Train Acc: 0.8866, Test Acc: 0.8874, Test AUC: 0.8929
# Epoch: 030, Train Acc: 0.8884, Test Acc: 0.8892, Test AUC: 0.8810
# Epoch: 031, Train Acc: 0.8874, Test Acc: 0.8911, Test AUC: 0.8690
# Epoch: 032, Train Acc: 0.8869, Test Acc: 0.8905, Test AUC: 0.8988
# Epoch: 033, Train Acc: 0.8874, Test Acc: 0.8856, Test AUC: 0.9286
# Epoch: 034, Train Acc: 0.8877, Test Acc: 0.8886, Test AUC: 0.8571
# Epoch: 035, Train Acc: 0.8877, Test Acc: 0.8874, Test AUC: 0.9405
# Epoch: 036, Train Acc: 0.8832, Test Acc: 0.8880, Test AUC: 0.9107
# Epoch: 037, Train Acc: 0.8866, Test Acc: 0.8868, Test AUC: 0.8690
# Epoch: 038, Train Acc: 0.8871, Test Acc: 0.8886, Test AUC: 0.9048
# Epoch: 039, Train Acc: 0.8854, Test Acc: 0.8837, Test AUC: 0.9405
# Epoch: 040, Train Acc: 0.8874, Test Acc: 0.8898, Test AUC: 0.8452
# Epoch: 041, Train Acc: 0.8874, Test Acc: 0.8843, Test AUC: 0.9107
# Epoch: 042, Train Acc: 0.8858, Test Acc: 0.8862, Test AUC: 0.8988
# Epoch: 043, Train Acc: 0.8881, Test Acc: 0.8868, Test AUC: 0.9167
# Epoch: 044, Train Acc: 0.8858, Test Acc: 0.8856, Test AUC: 0.8333
# Epoch: 045, Train Acc: 0.8900, Test Acc: 0.8880, Test AUC: 0.9107
# Epoch: 046, Train Acc: 0.8872, Test Acc: 0.8874, Test AUC: 0.8095
# Epoch: 047, Train Acc: 0.8886, Test Acc: 0.8898, Test AUC: 0.8214
# Epoch: 048, Train Acc: 0.8872, Test Acc: 0.8886, Test AUC: 0.8393
# Epoch: 049, Train Acc: 0.8898, Test Acc: 0.8917, Test AUC: 0.8988

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GATConv
from torch_geometric.nn import global_mean_pool, global_max_pool, global_add_pool


class GAT(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GAT, self).__init__()
        self.conv1 = GATConv(train_dataset.num_node_features, hidden_channels)
        self.conv2 = GATConv(hidden_channels, hidden_channels)
        self.conv3 = GATConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, train_dataset.num_classes)

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)

        # 2. Readout layer
        x = global_add_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)

        return x

model = GAT(hidden_channels=64)
print(model)
# Out:
# GAT(
#   (conv1): GATConv(50, 64, heads=1)
#   (conv2): GATConv(64, 64, heads=1)
#   (conv3): GATConv(64, 64, heads=1)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
model = GAT(hidden_channels=64)
print(model)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()
auroc = AUROC(task="binary")

def train():
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
         out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
         loss = criterion(out, data.y)  # Compute the loss.
         loss.backward()  # Derive gradients.
         optimizer.step()  # Update parameters based on gradients.
         optimizer.zero_grad()  # Clear gradients.

def test(loader):
     model.eval()

     correct = 0
     for data in loader:  # Iterate in batches over the training/test dataset.
         out = model(data.x, data.edge_index, data.batch)
         pred = out.argmax(dim=1)  # Use the class with highest probability.
         correct += int((pred == data.y).sum())  # Check against ground-truth labels.
     return (correct / len(loader.dataset), auroc(out.softmax(dim=1)[:, 1], data.y))  # Derive ratio of correct predictions.

for epoch in range(1, 50):
    train()
    train_acc, train_auc = test(train_loader)
    test_acc, test_auc = test(test_loader)
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}, Test AUC: {test_auc:.4f}')
# Out:
# GAT(
#   (conv1): GATConv(50, 64, heads=1)
#   (conv2): GATConv(64, 64, heads=1)
#   (conv3): GATConv(64, 64, heads=1)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )
# Epoch: 001, Train Acc: 0.8834, Test Acc: 0.8849, Test AUC: 0.7024
# Epoch: 002, Train Acc: 0.8834, Test Acc: 0.8849, Test AUC: 0.7679
# Epoch: 003, Train Acc: 0.8848, Test Acc: 0.8880, Test AUC: 0.7143
# Epoch: 004, Train Acc: 0.8840, Test Acc: 0.8898, Test AUC: 0.7143
# Epoch: 005, Train Acc: 0.8840, Test Acc: 0.8886, Test AUC: 0.7202
# Epoch: 006, Train Acc: 0.8836, Test Acc: 0.8886, Test AUC: 0.7500
# Epoch: 007, Train Acc: 0.8832, Test Acc: 0.8856, Test AUC: 0.7857
# Epoch: 008, Train Acc: 0.8845, Test Acc: 0.8892, Test AUC: 0.7619
# Epoch: 009, Train Acc: 0.8846, Test Acc: 0.8892, Test AUC: 0.7738
# Epoch: 010, Train Acc: 0.8836, Test Acc: 0.8849, Test AUC: 0.7500
# Epoch: 011, Train Acc: 0.8836, Test Acc: 0.8849, Test AUC: 0.7202
# Epoch: 012, Train Acc: 0.8836, Test Acc: 0.8849, Test AUC: 0.7440
# Epoch: 013, Train Acc: 0.8849, Test Acc: 0.8898, Test AUC: 0.7679
# Epoch: 014, Train Acc: 0.8851, Test Acc: 0.8905, Test AUC: 0.7976
# Epoch: 015, Train Acc: 0.8854, Test Acc: 0.8892, Test AUC: 0.7798
# Epoch: 016, Train Acc: 0.8852, Test Acc: 0.8898, Test AUC: 0.7679
# Epoch: 017, Train Acc: 0.8851, Test Acc: 0.8905, Test AUC: 0.7619
# Epoch: 018, Train Acc: 0.8840, Test Acc: 0.8849, Test AUC: 0.7381
# Epoch: 019, Train Acc: 0.8842, Test Acc: 0.8862, Test AUC: 0.7560
# Epoch: 020, Train Acc: 0.8837, Test Acc: 0.8849, Test AUC: 0.6726
# Epoch: 021, Train Acc: 0.8849, Test Acc: 0.8898, Test AUC: 0.7024
# Epoch: 022, Train Acc: 0.8839, Test Acc: 0.8862, Test AUC: 0.7262
# Epoch: 023, Train Acc: 0.8811, Test Acc: 0.8813, Test AUC: 0.8036
# Epoch: 024, Train Acc: 0.8846, Test Acc: 0.8886, Test AUC: 0.6964
# Epoch: 025, Train Acc: 0.8852, Test Acc: 0.8892, Test AUC: 0.7500
# Epoch: 026, Train Acc: 0.8837, Test Acc: 0.8862, Test AUC: 0.7917
# Epoch: 027, Train Acc: 0.8839, Test Acc: 0.8898, Test AUC: 0.7917
# Epoch: 028, Train Acc: 0.8851, Test Acc: 0.8898, Test AUC: 0.8095
# Epoch: 029, Train Acc: 0.8857, Test Acc: 0.8905, Test AUC: 0.7530
# Epoch: 030, Train Acc: 0.8839, Test Acc: 0.8862, Test AUC: 0.7143
# Epoch: 031, Train Acc: 0.8837, Test Acc: 0.8849, Test AUC: 0.6607
# Epoch: 032, Train Acc: 0.8848, Test Acc: 0.8892, Test AUC: 0.7143
# Epoch: 033, Train Acc: 0.8852, Test Acc: 0.8892, Test AUC: 0.7857
# Epoch: 034, Train Acc: 0.8843, Test Acc: 0.8892, Test AUC: 0.7917
# Epoch: 035, Train Acc: 0.8858, Test Acc: 0.8917, Test AUC: 0.8274
# Epoch: 036, Train Acc: 0.8834, Test Acc: 0.8849, Test AUC: 0.8155
# Epoch: 037, Train Acc: 0.8837, Test Acc: 0.8886, Test AUC: 0.7798
# Epoch: 038, Train Acc: 0.8846, Test Acc: 0.8880, Test AUC: 0.7440
# Epoch: 039, Train Acc: 0.8836, Test Acc: 0.8849, Test AUC: 0.7798
# Epoch: 040, Train Acc: 0.8840, Test Acc: 0.8892, Test AUC: 0.8125
# Epoch: 041, Train Acc: 0.8842, Test Acc: 0.8898, Test AUC: 0.7440
# Epoch: 042, Train Acc: 0.8846, Test Acc: 0.8892, Test AUC: 0.7976
# Epoch: 043, Train Acc: 0.8837, Test Acc: 0.8849, Test AUC: 0.7857
# Epoch: 044, Train Acc: 0.8848, Test Acc: 0.8898, Test AUC: 0.7560
# Epoch: 045, Train Acc: 0.8837, Test Acc: 0.8849, Test AUC: 0.7798
# Epoch: 046, Train Acc: 0.8849, Test Acc: 0.8898, Test AUC: 0.7143
# Epoch: 047, Train Acc: 0.8843, Test Acc: 0.8862, Test AUC: 0.7500
# Epoch: 048, Train Acc: 0.8852, Test Acc: 0.8831, Test AUC: 0.8036
# Epoch: 049, Train Acc: 0.8852, Test Acc: 0.8917, Test AUC: 0.7917
